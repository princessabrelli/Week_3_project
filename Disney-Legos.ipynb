# %%
import pandas as pd

# Define the file path
file_path = 'C:\\Users\\genes\\ih-labs\\Week_3_project\\lego_sets.csv'

# Read the CSV file into a DataFrame
legos_df = pd.read_csv(file_path)

# Print the DataFrame
print(legos_df)
# Out:
#          ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0      12-Jun     29.9900          2.0          277               4.0
# 1      12-Jun     19.9900          2.0          168               4.0
# 2      12-Jun     12.9900         11.0           74               4.3
# 3         12+     99.9900         23.0         1032               3.6
# 4         12+     79.9900         14.0          744               3.2
# ...       ...         ...          ...          ...               ...
# 12256  14-Jul     36.5878          6.0          341               4.4
# 12257  14-Jul     24.3878          8.0          217               4.1
# 12258  14-Jul     24.3878         18.0          233               4.6
# 12259  14-Jun     12.1878          1.0           48               5.0
# 12260  14-Jun     12.1878         11.0          109               4.5
#
#                                                prod_desc  prod_id  \
# ...

# %%
# Read the Disney dataset from the provided URL
disney_df = pd.read_csv("https://query.data.world/s/mkfcxqicohry4awyjy22wa6r3qg233?dws=00000")

# Display the first few rows of the DataFrame to ensure it's loaded correctly
print(disney_df.head())
# Out:
#                        movie_title  release_date      genre MPAA_rating  \
# 0  Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                        Pinocchio   Feb 9, 1940  Adventure           G
# 2                         Fantasia  Nov 13, 1940    Musical           G
# 3                Song of the South  Nov 12, 1946  Adventure           G
# 4                       Cinderella  Feb 15, 1950      Drama           G
#
#     total_gross inflation_adjusted_gross
# 0  $184,925,485           $5,228,953,251
# 1   $84,300,000           $2,188,229,052
# 2   $83,320,000           $2,187,090,808
# 3   $65,000,000           $1,078,510,579
# 4   $85,000,000             $920,608,730

# %%
disney_df.genre = disney_df['genre'].apply(lambda x: 'Comedy' if x in ['Romantic Comedy', 'Black Comedy'] else 'Thriller' if x in ['Thriller/Suspense', 'Horror'] else 'Musical' if x in ['Concert/Performance'] else x)
# Local file path to the downloaded CSV file

# %%
legos_df.drop(columns=['ages', 'num_reviews', 'play_star_rating', 'prod_desc', 'val_star_rating'], inplace=True)

legos_df
# Out:
#        list_price  piece_count  prod_id  \
# 0         29.9900          277    75823
# 1         19.9900          168    75822
# 2         12.9900           74    75821
# 3         99.9900         1032    21030
# 4         79.9900          744    21035
# ...           ...          ...      ...
# 12256     36.5878          341    70609
# 12257     24.3878          217    70629
# 12258     24.3878          233    70607
# 12259     12.1878           48    70628
# 12260     12.1878          109    70606
#
#                                           prod_long_desc review_difficulty  \
# 0      Use the staircase catapult to launch Red into ...           Average
# 1      Pilot Pig has taken off from Bird Island with ...              Easy
# 2      Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3      Discover the architectural secrets of the icon...           Average
# 4      Discover the architectural secrets of Frank Ll...       Challenging
# ...

# %%
legos_df.review_difficulty = legos_df['review_difficulty'].apply(lambda x: 'Easy' if x in ['Very Easy'] else ('Challenging' if x in ['Very Challenging'] else x))

# %%
legos_df['list_price'] = legos_df['list_price'].round(2)

legos_df
# Out:
#        list_price  piece_count  prod_id  \
# 0           29.99          277    75823
# 1           19.99          168    75822
# 2           12.99           74    75821
# 3           99.99         1032    21030
# 4           79.99          744    21035
# ...           ...          ...      ...
# 12256       36.59          341    70609
# 12257       24.39          217    70629
# 12258       24.39          233    70607
# 12259       12.19           48    70628
# 12260       12.19          109    70606
#
#                                           prod_long_desc review_difficulty  \
# 0      Use the staircase catapult to launch Red into ...           Average
# 1      Pilot Pig has taken off from Bird Island with ...              Easy
# 2      Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3      Discover the architectural secrets of the icon...           Average
# 4      Discover the architectural secrets of Frank Ll...       Challenging
# ...

# %%
legos_df.theme_name.value_counts()
# Out:
# theme_name
# Star Wars™                               1377
# DUPLO®                                   1166
# City                                     1092
# Juniors                                   978
# THE LEGO® NINJAGO® MOVIE™                 796
# BrickHeadz                                765
# Friends                                   606
# THE LEGO® BATMAN MOVIE                    533
# Technic                                   505
# Marvel Super Heroes                       414
# Creator 3-in-1                            403
# Classic                                   332
# Creator Expert                            317
# Minecraft™                                303
# Disney™                                   285
# DIMENSIONS™                               280
# MINDSTORMS®                               272
# NINJAGO®                                  263
# Speed Champions                           254
# Architecture                              210
# ...

# %%
mask = legos_df['prod_long_desc'].str.contains('Disney', case=False)

disneylegos_df = legos_df[mask]

disneylegos_df
# Out:
#        list_price  piece_count  prod_id  \
# 16          19.99          160    41613
# 36           9.99          118    41594
# 40           9.99          109    41593
# 42           9.99          139    41595
# 43           9.99          116    41596
# ...           ...          ...      ...
# 12000       18.29           67    10738
# 12002       12.19           47    10730
# 12003       12.19           62    10733
# 12004       12.19           75    10732
# 12005       12.19           59    10731
#
#                                           prod_long_desc review_difficulty  \
# 16     These LEGO® BrickHeadz™ 41613 Mr. Incredible &...              Easy
# 36     New for March 2017, LEGO® BrickHeadz construct...              Easy
# 40     New for March 2017, LEGO® BrickHeadz construct...              Easy
# 42     New for March 2017, LEGO® BrickHeadz construct...              Easy
# 43     New for March 2017, LEGO® BrickHeadz construct...           Average
# ...

# %%
# Create a new column "movie_titles" in lego_df by duplicating values from "set_name"
legos_df['movie_titles'] = legos_df['set_name'].copy()

# Display the modified DataFrame
print(legos_df)
# Out:
#        list_price  piece_count  prod_id  \
# 0           29.99          277    75823
# 1           19.99          168    75822
# 2           12.99           74    75821
# 3           99.99         1032    21030
# 4           79.99          744    21035
# ...           ...          ...      ...
# 12256       36.59          341    70609
# 12257       24.39          217    70629
# 12258       24.39          233    70607
# 12259       12.19           48    70628
# 12260       12.19          109    70606
#
#                                           prod_long_desc review_difficulty  \
# 0      Use the staircase catapult to launch Red into ...           Average
# 1      Pilot Pig has taken off from Bird Island with ...              Easy
# 2      Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3      Discover the architectural secrets of the icon...           Average
# 4      Discover the architectural secrets of Frank Ll...       Challenging
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [list_price, piece_count, prod_id, prod_long_desc, review_difficulty, set_name, star_rating, theme_name, country, movie_title, release_date, genre, MPAA_rating, total_gross, inflation_adjusted_gross]
# Index: []
